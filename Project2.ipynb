# %% [markdown]
# ### Question 1
#
# Initialize two variables, $p$ and $q$, to be the prime numbers 17 and 41 respectively.
#
# Then, set $n=p*q$

# %%
#Question 1


print('p =', p)
print('q =', q)
print('n =', n)

# %% [markdown]
# ### Question 2
#
# Now, we need to calculate $\phi(n)$. Initialize phi$=\phi(n)$.

# %%
#Question 2


print('phi =', phi)

# %% [markdown]
# ### Question 3
# Now we need to find a suitable integer $e$ such that gcd$(e,phi) = 1$. We will import the math package to calculate this.
#
# As an example, we will calculate gcd$(2,phi) =2$.
#
# Your task is to verify that $e=173$ is valid integer.

# %%
#Question 3
import math

print("gcd(2,phi)=", math.gcd(2,phi))
# Out:
# 2

# %% [markdown]
# ### Question 4
#
# Using print statements, report the public key and the private key.

# %%
#Question 4

# %% [markdown]
# ### Question 5
#
# Now we will switch to encryption. Using the values of $n$ and $e$, encode the number $m=62$ and report the ciphertext $c$.
#
# If you want to calculate $m^e$, you use the operation m**e
#
# <div class="alert alert-block alert-info">
#     <b>Tip: Raising m to the e power may be too large to solve directly. Make sure to use properties of modular arithmetic to solve the required equivalence for c.</b>
# </div>

# %%
#Question 5

# %% [markdown]
# ### Question 6
# Now it is time to decrypt $c$ back into the original message $m=62$.
#
# For an example of how to write a function in Python, the function findD, will be provided. This function solves the equation $dx \equiv 1\;\; ( mod\; \phi(n))$.
#
# Use said function to find the decryption exponent $d$.

# %%
#Question 6
def findD(e,phi):
    #solve equiv ex equiv 1 mod(phi)
    run=True
    check=1
    answer=0
    while(run):
        check=check+phi
        if (check % e==0):
            answer=(check/e) % phi
            run=False
    return int(answer)


d=findD(INSERT VALUE,INSERT VALUE)
print("d=",d)

# %% [markdown]
# ### Question 7
#
# Now that you have the ciphertext and the decryption exponent, compute the plaintext $m$ and report it.
# <div class="alert alert-block alert-info">
#     <b>Tip: Raising m to the d power may be too large to solve directly. Make sure to use properties of modular arithmetic to solve the required equivalence for c.</b>
# </div>

# %%
#Question 7

# %% [markdown]
# ### Question 8
#
# Create a function, factorN, which implements the factorization by squares technique. Use this function to recover the private key using the public key. That is, have the function return values $p$ and $q$.

# %%
#Question 8

# %% [markdown]
# ### Question 9
# Now we are able to encrypt and decrypt a singular number, we will now work with phrases. This requires using ASCII representation.
#
# Using the function provided in the cell below, translate the phrase "Ducks love using RSA cryptography!" into ASCII and report the list of numerical values as "plaintext".

# %%
def stringToAscii(string):
    return [ord(char) for char in string]

# %% [markdown]
# ### Question 10
#
# Now that we have the list, use the previous values of $n,e,\phi(n)$ and encrypt the list of ASCII numbers and report the list as "ciphertext_ASCII".
#
# <div class="alert alert-block alert-info">
#     <b>Tip: You will need to create a for loop to iterate through each entry of the list.</b>
# </div>

# %%
#Question 10

# %% [markdown]
# ### Question 11
#
# Let us change the public key to $(78267107,4427)$. Encrypt the ASCII numbers of the plain text and report the list as "ciphertext_ASCII".

# %%
#Question 11

# %% [markdown]
# ### Question 12
#
